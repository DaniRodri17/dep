# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniRodri17/dep/blob/main/keras_classification_liver_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestClassifier
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('Testing_indian_liver_disease_dataset.csv')
col_to_drop = ['Patient_ID', 'Occupation']
df.drop(col_to_drop, axis=1, inplace=True)
df.head()
# Out:
#    Age  Gender   BMI Obesity_Class Diet_Quality Physical_Activity  \
# 0   73    Male  30.6     Obesity I      Healthy         Sedentary
# 1   35  Female  23.5        Normal      Healthy          Moderate
# 2   36  Female  25.3    Overweight      Healthy         Sedentary
# 3   36    Male  15.0   Underweight      Healthy               Low
# 4   50  Female  30.0     Obesity I      Healthy               Low
#
#    Sleep_Hours Smoking_Status Alcohol_Consumption  Sym_Fatigue  ...  \
# 0          8.8          Never                 NaN            0  ...
# 1          9.0          Never            Moderate            1  ...
# 2          6.8          Never                 Low            0  ...
# 3          6.6          Never                 NaN            0  ...
# 4          6.3          Never            Moderate            1  ...
#
#    Comorb_Diabetes  Comorb_Hypertension  Comorb_Genetic_History    ALT    AST  \
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='constant', fill_value=0)
df['Alcohol_Consumption'] = imputer.fit_transform(df[['Alcohol_Consumption']])[:, 0]
df['Alcohol_Consumption'].isna().sum()
# Out:
# np.int64(0)

# %%
X = df.drop('Liver_Disease_Type', axis=1)
y = df['Liver_Disease_Type']

X = pd.get_dummies(X, columns=object_columns, dtype='int')
y = pd.get_dummies(y, dtype='int')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_test = pd.DataFrame(scaler.transform(X_test))

# %%
y_test.head()
# Out:
#       Alcoholic_Liver_Disease  Cirrhosis  Fatty_Liver  Hepatitis_B  \
# 1116                        0          0            1            0
# 1368                        1          0            0            0
# 422                         0          0            1            0
# 413                         0          0            1            0
# 451                         0          0            1            0
#
#       Hepatitis_C  Normal
# 1116            0       0
# 1368            0       0
# 422             0       0
# 413             0       0
# 451             0       0

# %%
model = Sequential([
    Dense(50, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(30, activation='relu'),
    Dropout(0.2),
    Dense(30, activation='relu'),
    Dropout(0.2),
    Dense(6, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['precision'])

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(x=X_train, y=y_train,
                    validation_data=(X_test, y_test),
                    batch_size=100,
                    epochs=500,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 1.8834 - precision: 0.2676 - val_loss: 1.6977 - val_precision: 0.0000e+00
# Epoch 2/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7264 - precision: 0.3769 - val_loss: 1.5956 - val_precision: 0.0000e+00
# Epoch 3/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6208 - precision: 0.4153 - val_loss: 1.5077 - val_precision: 0.0000e+00
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5231 - precision: 0.5090 - val_loss: 1.4237 - val_precision: 0.7273
# Epoch 5/500
# ...
